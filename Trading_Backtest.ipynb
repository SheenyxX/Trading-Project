# %%
import ccxt
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import logging
import json
from datetime import datetime, timedelta
from dataclasses import dataclass, field, asdict
from enum import Enum
from typing import List, Dict, Optional
from scipy.stats import percentileofscore

# ================== SETUP ==================
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

# Define the absolute path to config.json
CONFIG_PATH = r"C:\Users\drewr\OneDrive\Escritorio\Google Cloud Training\config.json"

# Load configuration from the JSON file
try:
    with open(CONFIG_PATH, 'r') as f:
        config = json.load(f)
except FileNotFoundError:
    logging.error(f"config.json file not found at {CONFIG_PATH}. Please check the path.")
    exit(1)

# Best-performing parameter configuration
BEST_PARAMS = {
    "MACD": [14, 28, 12],
    "MIN_TOTAL_SCORE": 4,
    "MIN_VOLUME_PERCENTILE": 30.0,
    "MIN_VOLATILITY_PERCENTILE": 30.0,
    "BASE_RISK_PER_TRADE": 0.03,
    "ATR_MULTIPLIER_SL": 1.0,
    "ADX_TREND_THRESHOLD": 30,
    "BB_PERIOD": 25
}

# ================== ENUMS AND DATA CLASSES ==================
class SignalType(Enum):
    LONG = 'LONG'
    SHORT = 'SHORT'
    EXIT = 'EXIT'
    NO_SIGNAL = 'NO_SIGNAL'

@dataclass
class TradingParams:
    MIN_TOTAL_SCORE: int = BEST_PARAMS["MIN_TOTAL_SCORE"]
    MIN_VOLUME_PERCENTILE: float = BEST_PARAMS["MIN_VOLUME_PERCENTILE"]
    MIN_VOLATILITY_PERCENTILE: float = BEST_PARAMS["MIN_VOLATILITY_PERCENTILE"]
    BASE_RISK_PER_TRADE: float = BEST_PARAMS["BASE_RISK_PER_TRADE"]
    ATR_MULTIPLIER_SL: float = BEST_PARAMS["ATR_MULTIPLIER_SL"]
    ADX_TREND_THRESHOLD: float = BEST_PARAMS["ADX_TREND_THRESHOLD"]
    BB_PERIOD: int = BEST_PARAMS["BB_PERIOD"]
    MAX_HOLDING_DAYS: int = 5  # Add this line to include MAX_HOLDING_DAYS

@dataclass
class TradeSignal:
    timestamp: datetime
    signal_type: SignalType
    entry_price: float
    stop_loss: float
    take_profits: List[float]
    position_size: float
    market_score: int
    market_condition: str
    risk_amount: float
    trade_id: str
    volume_percentile: float
    volatility_percentile: float
    macd_status: str
    atr: float
    ema_fast: float
    ema_slow: float
    macd_value: float
    signal_value: float
    adx_value: float
    bb_upper: float
    bb_lower: float

# ================== DATA FETCHER ==================
class DataFetcher:
    def __init__(self, symbol: str, timeframe: str = '1d'):
        self.symbol = symbol
        self.timeframe = timeframe

    def fetch_data(self, since: Optional[int] = None, limit: int = 1000) -> pd.DataFrame:
        """Fetch OHLCV data from Binance."""
        exchange = ccxt.binance()
        try:
            data = exchange.fetch_ohlcv(self.symbol, self.timeframe, since, limit)
            logging.info(f"Fetched {len(data)} rows of data for {self.symbol} ({self.timeframe})")
        except (ccxt.NetworkError, ccxt.ExchangeError) as e:
            logging.error(f"Error fetching data: {e}")
            return None

        df = pd.DataFrame(data, columns=['timestamp', 'open', 'high', 'low', 'close', 'volume'])
        df['timestamp'] = pd.to_datetime(df['timestamp'], unit='ms', utc=True)
        df.set_index('timestamp', inplace=True)

        # Calculate technical indicators
        df['volume_usd'] = df['volume'] * df['close']
        df['ema_fast'] = df['close'].ewm(span=BEST_PARAMS["MACD"][0], adjust=False).mean()
        df['ema_slow'] = df['close'].ewm(span=BEST_PARAMS["MACD"][1], adjust=False).mean()
        df['macd'] = df['ema_fast'] - df['ema_slow']
        df['signal'] = df['macd'].ewm(span=BEST_PARAMS["MACD"][2], adjust=False).mean()
        df['histogram'] = df['macd'] - df['signal']
        df['prev_close'] = df['close'].shift(1)
        df['TR'] = np.maximum(df['high'] - df['low'], np.maximum(abs(df['high'] - df['prev_close']), abs(df['low'] - df['prev_close'])))
        df['ATR'] = df['TR'].rolling(window=14).mean()
        df['volume_pct'] = df['volume_usd'].rolling(30).apply(lambda x: percentileofscore(x, x[-1]))
        df['atr_pct'] = df['ATR'].rolling(30).apply(lambda x: percentileofscore(x, x[-1]))
        df['EMA_20'] = df['close'].ewm(span=20, adjust=False).mean()
        df['EMA_50'] = df['close'].ewm(span=50, adjust=False).mean()

        # Calculate ADX
        df['plus_dm'] = df['high'].diff().apply(lambda x: x if x > 0 else 0)
        df['minus_dm'] = -df['low'].diff().apply(lambda x: x if x < 0 else 0)
        df['plus_di'] = 100 * (df['plus_dm'].ewm(span=14, adjust=False).mean() / df['ATR'])
        df['minus_di'] = 100 * (df['minus_dm'].ewm(span=14, adjust=False).mean() / df['ATR'])
        df['dx'] = 100 * abs(df['plus_di'] - df['minus_di']) / (df['plus_di'] + df['minus_di'])
        df['ADX'] = df['dx'].ewm(span=14, adjust=False).mean()

        # Calculate Bollinger Bands
        df['BB_middle'] = df['close'].rolling(window=BEST_PARAMS["BB_PERIOD"]).mean()
        df['BB_std'] = df['close'].rolling(window=BEST_PARAMS["BB_PERIOD"]).std()
        df['BB_upper'] = df['BB_middle'] + (2 * df['BB_std'])
        df['BB_lower'] = df['BB_middle'] - (2 * df['BB_std'])

        logging.info(f"Data sample with indicators:\n{df.tail()}")
        return df

# ================== STRATEGY ENGINE ==================
class StrategyEngine:
    def __init__(self, params: TradingParams, timeframe: str = '1d'):
        self.params = params
        self.timeframe = timeframe
        self._adjust_parameters_for_timeframe()

    def _adjust_parameters_for_timeframe(self):
        """Dynamically adjust parameters based on timeframe."""
        if self.timeframe == '1h':
            self.params.BB_PERIOD = 20
            self.params.ADX_TREND_THRESHOLD = 20
            self.params.ATR_MULTIPLIER_SL = 1.0
        elif self.timeframe == '4h':
            self.params.BB_PERIOD = 20
            self.params.ADX_TREND_THRESHOLD = 22
            self.params.ATR_MULTIPLIER_SL = 1.2

    def calculate_stop_loss(self, entry_price: float, atr: float, signal_type: SignalType) -> float:
        """Calculate stop-loss based on ATR multiplier."""
        if signal_type == SignalType.LONG:
            return entry_price - (atr * self.params.ATR_MULTIPLIER_SL)
        return entry_price + (atr * self.params.ATR_MULTIPLIER_SL)

    def calculate_take_profits(self, entry_price: float, stop_loss: float, signal_type: SignalType) -> List[float]:
        """Calculate take-profit levels based on risk-reward ratios."""
        risk = abs(entry_price - stop_loss)
        if signal_type == SignalType.LONG:
            return [entry_price + (risk * r) for r in [1.5, 2.5, 3.5]]
        return [entry_price - (risk * r) for r in [1.5, 2.5, 3.5]]

    def calculate_position_size(self, account_size: float, entry_price: float, stop_loss: float, risk_percentage: float) -> float:
        """Calculate position size based on risk percentage."""
        risk_amount = account_size * risk_percentage
        risk_per_unit = abs(entry_price - stop_loss)
        return risk_amount / risk_per_unit if risk_per_unit != 0 else 0

    def generate_trade_signal(self, df: pd.DataFrame, account_size: float = 100000) -> Optional[TradeSignal]:
        """Generate a trade signal based on the strategy logic."""
        current = df.iloc[-1]
        logging.info(f"Current data:\n{current}")

        # Check volume/volatility thresholds
        if (current['volume_pct'] < self.params.MIN_VOLUME_PERCENTILE or
            current['atr_pct'] < self.params.MIN_VOLATILITY_PERCENTILE):
            logging.info("Volume or volatility below threshold. No signal generated.")
            return None

        # Determine market condition
        is_sideways = current['ADX'] < self.params.ADX_TREND_THRESHOLD
        is_bullish_trend = current['EMA_20'] > current['EMA_50'] and current['ADX'] >= self.params.ADX_TREND_THRESHOLD
        is_bearish_trend = current['EMA_20'] < current['EMA_50'] and current['ADX'] >= self.params.ADX_TREND_THRESHOLD

        # Initialize variables
        signal_type = None
        stop_loss = None
        risk_percentage = None
        near_support = False
        near_resistance = False
        macd_turning_up = False
        macd_turning_down = False

        # --- Sideways Market Strategy ---
        if is_sideways:
            macd_turning_up = (current['histogram'] > 0) and (df['histogram'].iloc[-2] <= 0)
            macd_turning_down = (current['histogram'] < 0) and (df['histogram'].iloc[-2] >= 0)

            buffer = current['ATR'] * 0.5
            near_support = current['close'] <= (current['BB_lower'] + buffer)
            near_resistance = current['close'] >= (current['BB_upper'] - buffer)

        if near_support and macd_turning_up:
            signal_type = SignalType.LONG
            stop_loss = current['BB_lower'] - (current['ATR'] * 1.0)
            risk_percentage = self.params.BASE_RISK_PER_TRADE
        elif near_resistance and macd_turning_down:
            signal_type = SignalType.SHORT
            stop_loss = current['BB_upper'] + (current['ATR'] * 1.0)
            risk_percentage = self.params.BASE_RISK_PER_TRADE

        # --- Trend-Following Strategy ---
        elif is_bullish_trend and current['macd'] > current['signal']:
            signal_type = SignalType.LONG
            stop_loss = self.calculate_stop_loss(current['close'], current['ATR'], signal_type)
            risk_percentage = self.params.BASE_RISK_PER_TRADE
        elif is_bearish_trend and current['macd'] < current['signal']:
            signal_type = SignalType.SHORT
            stop_loss = self.calculate_stop_loss(current['close'], current['ATR'], signal_type)
            risk_percentage = self.params.BASE_RISK_PER_TRADE

        if not signal_type:
            return None

        # Position sizing
        position_size = self.calculate_position_size(account_size, current['close'], stop_loss, risk_percentage)
        take_profits = self.calculate_take_profits(current['close'], stop_loss, signal_type)

        # Generate unique trade ID
        trade_id = f"{signal_type.value}_{datetime.now().strftime('%Y%m%d_%H%M%S')}"

        # Calculate market score based on conditions
        market_score = sum([
            1 if current['volume_pct'] > self.params.MIN_VOLUME_PERCENTILE else 0,
            1 if current['atr_pct'] > self.params.MIN_VOLATILITY_PERCENTILE else 0,
            1 if is_sideways and (near_support or near_resistance) else 0,
            1 if (is_bullish_trend or is_bearish_trend) else 0
        ])

        # Determine market condition string
        if is_sideways:
            market_condition = "Sideways"
        elif is_bullish_trend:
            market_condition = "Bullish"
        else:
            market_condition = "Bearish"

        # Create and return the TradeSignal
        return TradeSignal(
            timestamp=df.index[-1],
            signal_type=signal_type,
            entry_price=current['close'],
            stop_loss=stop_loss,
            take_profits=take_profits,
            position_size=position_size,
            market_score=market_score,
            market_condition=market_condition,
            risk_amount=account_size * risk_percentage,
            trade_id=trade_id,
            volume_percentile=current['volume_pct'],
            volatility_percentile=current['atr_pct'],
            macd_status="Bullish" if current['macd'] > current['signal'] else "Bearish",
            atr=current['ATR'],
            ema_fast=current['ema_fast'],
            ema_slow=current['ema_slow'],
            macd_value=current['macd'],
            signal_value=current['signal'],
            adx_value=current['ADX'],
            bb_upper=current['BB_upper'],
            bb_lower=current['BB_lower']
        )

# ================== TRADE MANAGER ==================
class TradeManager:
    def __init__(self, trading_rules: StrategyEngine):
        self.trading_rules = trading_rules
        self.active_trades: Dict[str, TradeSignal] = {}
        self.trade_history: List[Dict] = []

    def backtest(self, df: pd.DataFrame):
        """Backtest the strategy on historical data."""
        logging.info(f"Starting backtest with {len(df)} rows of data.")
        for i in range(len(df)):
            current_time = df.index[i]
            current_data = df.iloc[:i+1]
            self.update(current_data, current_time)

    def update(self, df: pd.DataFrame, current_time: datetime):
        """Update trade management system with new data."""
        self._check_exits(df, current_time)
        if len(self.active_trades) < 3:  # Maximum 3 concurrent trades
            signal = self.trading_rules.generate_trade_signal(df)
            if signal:
                self._process_new_signal(signal)

    def _check_exits(self, df: pd.DataFrame, current_time: datetime):
        """Check all active trades for exit signals."""
        current_price = df.iloc[-1]['close']
        for trade_id, trade in list(self.active_trades.items()):
            exit_signal = self._check_exit_conditions(df, trade, current_time, current_price)
            if exit_signal:
                self._close_trade(trade_id, current_price, current_time, exit_signal)

    def _check_exit_conditions(self, df: pd.DataFrame, trade: TradeSignal, current_time: datetime, current_price: float) -> Optional[str]:
        """Check various exit conditions."""
        if (trade.signal_type == SignalType.LONG and current_price <= trade.stop_loss or
            trade.signal_type == SignalType.SHORT and current_price >= trade.stop_loss):
            return "Stop Loss"
        for i, tp in enumerate(trade.take_profits):
            if (trade.signal_type == SignalType.LONG and current_price >= tp or
                trade.signal_type == SignalType.SHORT and current_price <= tp):
                return f"Take Profit {i+1}"
        if (current_time - trade.timestamp) > timedelta(days=self.trading_rules.params.MAX_HOLDING_DAYS):
            return "Max Hold Time"
        return None

    def _process_new_signal(self, signal: TradeSignal):
        """Process a new trade signal."""
        self.active_trades[signal.trade_id] = signal

    def _close_trade(self, trade_id: str, exit_price: float, exit_time: datetime, exit_reason: str):
        """Close a trade and record it in history."""
        trade = self.active_trades[trade_id]
        pnl = (exit_price - trade.entry_price) * trade.position_size if trade.signal_type == SignalType.LONG else (trade.entry_price - exit_price) * trade.position_size
        holding_days = (exit_time - trade.timestamp).days
        trade_record = {
            'trade_id': trade_id,
            'timestamp': trade.timestamp,  # Use 'timestamp' instead of 'entry_time'
            'exit_time': exit_time,
            'signal_type': trade.signal_type.value,
            'entry_price': trade.entry_price,
            'exit_price': exit_price,
            'position_size': trade.position_size,
            'pnl': pnl,
            'holding_days': holding_days,
            'exit_reason': exit_reason,
            'market_score': trade.market_score,
            'risk_amount': trade.risk_amount
        }
        self.trade_history.append(trade_record)
        del self.active_trades[trade_id]

    def calculate_performance_metrics(self, lookback_days: int) -> Dict:
        """Calculate performance metrics including requested metrics."""
        if not self.trade_history:
            return {
                "total_trades": 0,
                "win_rate": 0.0,
                "profit_factor": 0.0,
                "average_profit": 0.0,
                "max_drawdown": 0.0,
                "sharpe_ratio": 0.0,
                "avg_holding_time": "0 days",
                "aggregated_returns": 0.0,
                "best_trade": 0.0,
                "worst_trade": 0.0,
                "average_trade_pct": 0.0,
                "days_reviewed": lookback_days,
                "trade_details": []
            }

        df = pd.DataFrame(self.trade_history)
        df['pnl_pct'] = df['pnl'] / df['risk_amount'] * 100

        # Calculate cumulative PnL
        df['cumulative_pnl'] = df['pnl'].cumsum()

        # Add trade details
        trade_details = df[['timestamp', 'exit_time', 'entry_price', 'exit_price', 'pnl', 'holding_days', 'exit_reason']].to_dict('records')

        return {
            "total_trades": len(df),
            "win_rate": (len(df[df['pnl'] > 0]) / len(df)) * 100,
            "profit_factor": df[df['pnl'] > 0]['pnl'].sum() / abs(df[df['pnl'] <= 0]['pnl'].sum()),
            "average_profit": df['pnl'].mean(),
            "max_drawdown": (df['cumulative_pnl'].max() - df['cumulative_pnl'].min()),
            "sharpe_ratio": np.sqrt(252) * (df['pnl'].mean() / df['pnl'].std()),
            "avg_holding_time": str((df['exit_time'] - df['timestamp']).mean()),
            "aggregated_returns": df['pnl'].sum(),
            "best_trade": df['pnl'].max(),
            "worst_trade": df['pnl'].min(),
            "average_trade_pct": df['pnl_pct'].mean(),
            "days_reviewed": lookback_days,
            "trade_details": trade_details
        }

# ================== MAIN FUNCTION ==================
def main():
    symbol = 'BTC/USDT'
    account_size = 100000
    timeframe = '1d'  # Use the best-performing timeframe

    # Load configuration from the JSON file
    try:
        with open(CONFIG_PATH, 'r') as f:
            config = json.load(f)
    except FileNotFoundError:
        logging.error(f"config.json file not found at {CONFIG_PATH}. Please check the path.")
        exit(1)

    lookback_days = config.get("LOOKBACK_DAYS", 180)  # Get LOOKBACK_DAYS from config

    # Fetch data
    data_fetcher = DataFetcher(symbol, timeframe)
    df = data_fetcher.fetch_data()

    if df is not None:
        # Initialize TradingParams with the best configuration
        trading_params = TradingParams()
        strategy_engine = StrategyEngine(trading_params, timeframe)
        trade_manager = TradeManager(strategy_engine)

        # Run the backtest
        trade_manager.backtest(df)

        # Calculate performance metrics
        metrics = trade_manager.calculate_performance_metrics(lookback_days)  # Pass lookback_days
        logging.info("\nPerformance Metrics:")
        for key, value in metrics.items():
            logging.info(f"{key}: {value}")

        # Export trade details to CSV
        trade_details_df = pd.DataFrame(metrics['trade_details'])
        trade_details_df.to_csv('trade_details.csv', index=False)
        logging.info("Trade details exported to trade_details.csv")

        # Export signals for successful and failed trades
        successful_trades = trade_details_df[trade_details_df['pnl'] > 0]
        failed_trades = trade_details_df[trade_details_df['pnl'] <= 0]

        successful_trades.to_csv('successful_trades.csv', index=False)
        failed_trades.to_csv('failed_trades.csv', index=False)
        logging.info("Successful trades exported to successful_trades.csv")
        logging.info("Failed trades exported to failed_trades.csv")

        # Export signals and parameters to CSV
        signals_df = pd.DataFrame([asdict(TradeSignal(
            timestamp=trade['timestamp'],  # Map 'timestamp' from trade_history
            signal_type=SignalType(trade['signal_type']),  # Convert string to SignalType enum
            entry_price=trade['entry_price'],
            stop_loss=None,  # Add missing required fields with default values
            take_profits=[],
            position_size=trade['position_size'],
            market_score=trade['market_score'],
            market_condition="",  # Add missing required fields with default values
            risk_amount=trade['risk_amount'],
            trade_id=trade['trade_id'],
            volume_percentile=0.0,  # Add missing required fields with default values
            volatility_percentile=0.0,
            macd_status="",
            atr=0.0,
            ema_fast=0.0,
            ema_slow=0.0,
            macd_value=0.0,
            signal_value=0.0,
            adx_value=0.0,
            bb_upper=0.0,
            bb_lower=0.0
        )) for trade in trade_manager.trade_history])
        signals_df.to_csv('signals_and_parameters.csv', index=False)
        logging.info("Signals and parameters exported to signals_and_parameters.csv")

if __name__ == "__main__":
    main()
# Out:
# 2025-02-22 06:47:08,085 - INFO - Fetched 1000 rows of data for BTC/USDT (1d)
# C:\Users\drewr\AppData\Local\Temp\ipykernel_21252\3250624363.py:111: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   df['volume_pct'] = df['volume_usd'].rolling(30).apply(lambda x: percentileofscore(x, x[-1]))
# C:\Users\drewr\AppData\Local\Temp\ipykernel_21252\3250624363.py:112: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   df['atr_pct'] = df['ATR'].rolling(30).apply(lambda x: percentileofscore(x, x[-1]))
# 2025-02-22 06:47:08,275 - INFO - Data sample with indicators:
#                                open      high       low     close  \
# timestamp
# 2025-02-18 00:00:00+00:00  95780.01  96753.91  93388.09  95671.74
# 2025-02-19 00:00:00+00:00  95671.74  96899.99  95029.99  96644.37
# 2025-02-20 00:00:00+00:00  96644.37  98711.36  96415.09  98305.00
# 2025-02-21 00:00:00+00:00  98305.01  99475.00  94871.95  96181.98
# 2025-02-22 00:00:00+00:00  96181.99  96595.00  95770.49  96573.89
#
#                                 volume    volume_usd      ema_fast  \
# timestamp
# 2025-02-18 00:00:00+00:00  23368.19471  2.235676e+09  97151.609704
# 2025-02-19 00:00:00+00:00  16438.50954  1.588689e+09  97083.977743
# 2025-02-20 00:00:00+00:00  17057.39177  1.676827e+09  97246.780711
# 2025-02-21 00:00:00+00:00  32249.28140  3.101800e+09  97104.807283
# 2025-02-22 00:00:00+00:00   5590.66486  5.399123e+08  97034.018312
#
#                                ema_slow        macd      signal  ...  plus_dm  \
# timestamp                                                        ...
# 2025-02-18 00:00:00+00:00  98089.722887 -938.113184 -586.027104  ...     0.00
# 2025-02-19 00:00:00+00:00  97990.043378 -906.065635 -635.263801  ...   146.08
# 2025-02-20 00:00:00+00:00  98011.764524 -764.983813 -655.220726  ...  1811.37
# 2025-02-21 00:00:00+00:00  97885.572488 -780.765205 -674.535261  ...   763.64
# 2025-02-22 00:00:00+00:00  97795.111627 -761.093315 -687.851885  ...     0.00
#
#                            minus_dm    plus_di   minus_di         dx  \
# timestamp
# 2025-02-18 00:00:00+00:00   1816.91   7.987851  28.630602  56.372536
# 2025-02-19 00:00:00+00:00     -0.00   7.859718  25.558721  52.961787
# 2025-02-20 00:00:00+00:00     -0.00  16.351552  22.851591  16.580403
# 2025-02-21 00:00:00+00:00   1543.14  18.059774  27.683080  21.037835
# 2025-02-22 00:00:00+00:00     -0.00  15.811666  24.237048  21.037835
#
#                                  ADX   BB_middle       BB_std       BB_upper  \
# timestamp
# 2025-02-18 00:00:00+00:00  35.888364  98880.2820  3053.102070  104986.486140
# 2025-02-19 00:00:00+00:00  38.164820  98556.1828  2826.003134  104208.189067
# 2025-02-20 00:00:00+00:00  35.286898  98383.5828  2696.253285  103776.089370
# 2025-02-21 00:00:00+00:00  33.387023  98147.5488  2616.013080  103379.574960
# 2025-02-22 00:00:00+00:00  31.740464  97957.0836  2546.655513  103050.394627
#
#                                BB_lower
# timestamp
# 2025-02-18 00:00:00+00:00  92774.077860
# 2025-02-19 00:00:00+00:00  92904.176533
# 2025-02-20 00:00:00+00:00  92991.076230
# 2025-02-21 00:00:00+00:00  92915.522640
# 2025-02-22 00:00:00+00:00  92863.772573
#
# [5 rows x 28 columns]
# 2025-02-22 06:47:08,305 - INFO - Starting backtest with 1000 rows of data.
# 2025-02-22 06:47:08,308 - INFO - Current data:
# open          2.946810e+04
# high          3.222200e+04
# low           2.929962e+04
# close         3.173422e+04
# volume        9.678595e+04
# volume_usd    3.071427e+09
# ema_fast      3.173422e+04
# ema_slow      3.173422e+04
# macd          0.000000e+00
# signal        0.000000e+00
# histogram     0.000000e+00
# prev_close             NaN
# TR                     NaN
# ATR                    NaN
# volume_pct             NaN
# atr_pct                NaN
# EMA_20        3.173422e+04
# EMA_50        3.173422e+04
# plus_dm       0.000000e+00
# minus_dm     -0.000000e+00
# plus_di                NaN
# minus_di               NaN
# dx                     NaN
# ADX                    NaN
# BB_middle              NaN
# BB_std                 NaN
# BB_upper               NaN
# BB_lower               NaN
# Name: 2022-05-30 00:00:00+00:00, dtype: float64
# 2025-02-22 06:47:08,312 - INFO - Current data:
# open          3.173423e+04
# high          3.239900e+04
# low           3.120001e+04
# close         3.180104e+04
# volume        6.243312e+04
# volume_usd    1.985438e+09
# ema_fast      3.174313e+04
# ema_slow      3.173883e+04
# macd          4.301057e+00
# signal        6.617011e-01
# histogram     3.639356e+00
# prev_close    3.173422e+04
# TR            1.198990e+03
# ATR                    NaN
# volume_pct             NaN
# atr_pct                NaN
# EMA_20        3.174058e+04
# EMA_50        3.173684e+04
# plus_dm       1.770000e+02
# minus_dm     -0.000000e+00
# plus_di                NaN
# minus_di               NaN
# dx                     NaN
# ADX                    NaN
# BB_middle              NaN
# BB_std                 NaN
# BB_upper               NaN
# BB_lower               NaN
# Name: 2022-05-31 00:00:00+00:00, dtype: float64
# 2025-02-22 06:47:08,316 - INFO - Current data:
# open          3.180105e+04
# high          3.198297e+04
# low           2.930100e+04
# close         2.980583e+04
# volume        1.033956e+05
# volume_usd    3.081793e+09
# ema_fast      3.148482e+04
# ema_slow      3.160552e+04
# macd         -1.206953e+02
# signal       -1.800861e+01
# histogram    -1.026867e+02
# prev_close    3.180104e+04
# TR            2.681970e+03
# ATR                    NaN
# volume_pct             NaN
# atr_pct                NaN
# EMA_20        3.155632e+04
# EMA_50        3.166111e+04
# plus_dm       0.000000e+00
# minus_dm      1.899010e+03
# plus_di                NaN
# minus_di               NaN
# dx                     NaN
# ADX                    NaN
# BB_middle              NaN
# BB_std                 NaN
# BB_upper               NaN
# BB_lower               NaN
# Name: 2022-06-01 00:00:00+00:00, dtype: float64
# 2025-02-22 06:47:08,320 - INFO - Current data:
# open          2.980584e+04
# high          3.068900e+04
# low           2.959455e+04
# close         3.045262e+04
# volume        5.696143e+04
# volume_usd    1.734625e+09
# ema_fast      3.134720e+04
# ema_slow      3.152601e+04
# macd         -1.788121e+02
# signal       -4.274761e+01
# histogram    -1.360645e+02
# prev_close    2.980583e+04
# TR            1.094450e+03
# ATR                    NaN
# volume_pct             NaN
# atr_pct                NaN
# EMA_20        3.145121e+04
# EMA_50        3.161372e+04
# plus_dm       0.000000e+00
# minus_dm     -0.000000e+00
# plus_di                NaN
# minus_di               NaN
# dx                     NaN
# ADX                    NaN
# BB_middle              NaN
# BB_std                 NaN
# BB_upper               NaN
# BB_lower               NaN
# Name: 2022-06-02 00:00:00+00:00, dtype: float64
# 2025-02-22 06:47:08,323 - INFO - Current data:
# open          3.045263e+04
# high          3.069900e+04
# low           2.928236e+04
# close         2.970021e+04
# volume        5.406745e+04
# volume_usd    1.605815e+09
# ema_fast      3.112760e+04
# ema_slow      3.140009e+04
# macd         -2.724931e+02
# signal       -7.809307e+01
# histogram    -1.944001e+02
# prev_close    3.045262e+04
# TR            1.416640e+03
# ATR                    NaN
# volume_pct             NaN
# atr_pct                NaN
# EMA_20        3.128445e+04
# EMA_50        3.153868e+04
# plus_dm       1.000000e+01
# minus_dm      3.121900e+02
# plus_di                NaN
# minus_di               NaN
# dx                     NaN
# ADX                    NaN
# BB_middle              NaN
# BB_std                 NaN
# BB_upper               NaN
# BB_lower               NaN
# Name: 2022-06-03 00:00:00+00:00, dtype: float64
# 2025-02-22 06:47:08,326 - INFO - Current data:
# open          2.970021e+04
# high          2.998888e+04
# low           2.948500e+04
# close         2.986404e+04
# volume        2.561790e+04
# volume_usd    7.650540e+08
# ema_fast      3.095912e+04
# ema_slow      3.129416e+04
# macd         -3.350329e+02
# signal       -1.176223e+02
# histogram    -2.174107e+02
# prev_close    2.970021e+04
# TR            5.038800e+02
# ATR                    NaN
# volume_pct             NaN
# atr_pct                NaN
# EMA_20        3.114917e+04
# EMA_50        3.147301e+04
# plus_dm       0.000000e+00
# minus_dm     -0.000000e+00
# plus_di                NaN
# minus_di               NaN
# dx                     NaN
# ADX                    NaN
# BB_middle              NaN
# BB_std                 NaN
# BB_upper               NaN
# BB_lower               NaN
# Name: 2022-06-04 00:00:00+00:00, dtype: float64
# 2025-02-22 06:47:08,330 - INFO - Current data:
# open          2.986403e+04
# high          3.018900e+04
# low           2.953142e+04
# close         2.991921e+04
# volume        2.313993e+04
# volume_usd    6.923284e+08
# ema_fast      3.082047e+04
# ema_slow      3.119933e+04
# macd         -3.788642e+02
# signal       -1.578133e+02
# histogram    -2.210508e+02
# prev_close    2.986404e+04
# TR            6.575800e+02
# ATR                    NaN
# volume_pct             NaN
# atr_pct                NaN
# EMA_20        3.103203e+04
# EMA_50        3.141208e+04
# plus_dm       2.001200e+02
# minus_dm     -0.000000e+00
# plus_di                NaN
# minus_di               NaN
# dx                     NaN
# ADX                    NaN
# BB_middle              NaN
# BB_std                 NaN
# BB_upper               NaN
# BB_lower               NaN
# Name: 2022-06-05 00:00:00+00:00, dtype: float64
# 2025-02-22 06:47:08,333 - INFO - Current data:
# open          2.991920e+04
# high          3.176564e+04
# low           2.989023e+04
# close         3.137310e+04
# volume        6.883692e+04
# volume_usd    2.159628e+09
# ema_fast      3.089415e+04
# ema_slow      3.121132e+04
# macd         -3.171639e+02
# signal       -1.823288e+02
# histogram    -1.348351e+02
# prev_close    2.991921e+04
# TR            1.875410e+03
# ATR                    NaN
# volume_pct             NaN
# atr_pct                NaN
# EMA_20        3.106451e+04
# EMA_50        3.141055e+04
# plus_dm       1.576640e+03
# minus_dm     -0.000000e+00
# plus_di                NaN
# minus_di               NaN
# dx                     NaN
# ADX                    NaN
# BB_middle              NaN
# BB_std                 NaN
# BB_upper               NaN
# BB_lower               NaN
# Name: 2022-06-06 00:00:00+00:00, dtype: float64
# 2025-02-22 06:47:08,335 - INFO - Current data:
# open          3.137310e+04
# high          3.158960e+04
# low           2.921896e+04
# close         3.112533e+04
# volume        1.106745e+05
# volume_usd    3.444781e+09
# ema_fast      3.092498e+04
# ema_slow      3.120539e+04
# macd         -2.804101e+02
# signal       -1.974182e+02
# histogram    -8.299188e+01
# prev_close    3.137310e+04
# TR            2.370640e+03
# ATR                    NaN
# volume_pct             NaN
# atr_pct                NaN
# EMA_20        3.107030e+04
# EMA_50        3.139936e+04
# plus_dm       0.000000e+00
# minus_dm      6.712700e+02
# plus_di                NaN
# minus_di               NaN
# dx                     NaN
# ADX                    NaN
# BB_middle              NaN
# BB_std                 NaN
# BB_upper               NaN
# BB_lower               NaN
# Name: 2022-06-07 00:00:00+00:00, dtype: float64
# 2025-02-22 06:47:08,339 - INFO - Current data:
# open          3.112532e+04
# high          3.132722e+04
# low           2.984388e+04
# close         3.020477e+04
# volume        6.854261e+04
# volume_usd    2.070314e+09
# ema_fast      3.082895e+04
# ema_slow      3.113638e+04
# macd         -3.074296e+02
# signal       -2.143431e+02
# histogram    -9.308653e+01
# prev_close    3.112533e+04
# TR            1.483340e+03
# ATR                    NaN
# volume_pct             NaN
# atr_pct                NaN
# EMA_20        3.098787e+04
# EMA_50        3.135252e+04
# plus_dm       0.000000e+00
# minus_dm     -0.000000e+00
# plus_di                NaN
# minus_di               NaN
# dx                     NaN
# ADX                    NaN
# BB_middle              NaN
# BB_std                 NaN
# BB_upper               NaN
# BB_lower               NaN
# Name: 2022-06-08 00:00:00+00:00, dtype: float64
# 2025-02-22 06:47:08,342 - INFO - Current data:
# open          3.020477e+04
# high          3.070000e+04
# low           2.994410e+04
# close         3.010993e+04
# volume        4.629119e+04
# volume_usd    1.393824e+09
# ema_fast      3.073308e+04
# ema_slow      3.106559e+04
# macd         -3.325092e+02
# signal       -2.325225e+02
# histogram    -9.998674e+01
# prev_close    3.020477e+04
# TR            7.559000e+02
# ATR                    NaN
# volume_pct             NaN
# atr_pct                NaN
# EMA_20        3.090426e+04
# EMA_50        3.130379e+04
# plus_dm       0.000000e+00
# minus_dm     -0.000000e+00
# plus_di                NaN
# minus_di               NaN
# dx                     NaN
# ADX                    NaN
# BB_middle              NaN
# BB_std                 NaN
# BB_upper               NaN
# BB_lower               NaN
# Name: 2022-06-09 00:00:00+00:00, dtype: float64
# 2025-02-22 06:47:08,345 - INFO - Current data:
# open          3.010993e+04
# high          3.038280e+04
# low           2.885000e+04
# close         2.909188e+04
# volume        7.620425e+04
# volume_usd    2.216925e+09
# ema_fast      3.051425e+04
# ema_slow      3.092947e+04
# macd         -4.152180e+02
# signal       -2.606295e+02
# histogram    -1.545885e+02
# prev_close    3.010993e+04
# TR            1.532800e+03
# ATR                    NaN
# volume_pct             NaN
# atr_pct                NaN
# EMA_20        3.073165e+04
# EMA_50        3.121705e+04
# plus_dm       0.000000e+00
# minus_dm      1.094100e+03
# plus_di                NaN
# minus_di               NaN
# dx                     NaN
# ADX                    NaN
# BB_middle              NaN
# BB_std                 NaN
# BB_upper               NaN
# BB_lower               NaN
# Name: 2022-06-10 00:00:00+00:00, dtype: float64
# 2025-02-22 06:47:08,347 - INFO - Current data:
# open          2.909187e+04
# high          2.944041e+04
# low           2.809999e+04
# close         2.842470e+04
# volume        6.590140e+04
# volume_usd    1.873227e+09
# ema_fast      3.023565e+04
# ema_slow      3.075673e+04
# macd         -5.210822e+02
# signal       -3.006991e+02
# histogram    -2.203831e+02
# prev_close    2.909188e+04
# TR            1.340420e+03
# ATR                    NaN
# volume_pct             NaN
# atr_pct                NaN
# EMA_20        3.051194e+04
# EMA_50        3.110754e+04
# plus_dm       0.000000e+00
# minus_dm      7.500100e+02
# plus_di                NaN
# minus_di               NaN
# dx                     NaN
# ADX                    NaN
# BB_middle              NaN
# BB_std                 NaN
# BB_upper               NaN
# BB_lower               NaN
# Name: 2022-06-11 00:00:00+00:00, dtype: float64
# 2025-02-22 06:47:08,349 - INFO - Current data:
# open          2.842471e+04
# high          2.854496e+04
# low           2.656000e+04
# close         2.657453e+04
# volume        9.247460e+04
# volume_usd    2.457469e+09
# ema_fast      2.974750e+04
# ema_slow      3.046830e+04
# macd         -7.208035e+02
# signal       -3.653306e+02
# histogram    -3.554730e+02
# prev_close    2.842470e+04
# TR            1.984960e+03
# ATR                    NaN
# volume_pct             NaN
# atr_pct                NaN
# EMA_20        3.013695e+04
# EMA_50        3.092978e+04
# plus_dm       0.000000e+00
# minus_dm      1.539990e+03
# plus_di                NaN
# minus_di               NaN
# dx                     NaN
# ADX                    NaN
# BB_middle              NaN
# BB_std                 NaN
# BB_upper               NaN
# BB_lower               NaN
# Name: 2022-06-12 00:00:00+00:00, dtype: float64
# 2025-02-22 06:47:08,353 - INFO - Current data:
# open          2.657453e+04
# high          2.689584e+04
# low           2.192577e+04
# close         2.248741e+04
# volume        2.546110e+05
# volume_usd    5.725543e+09
# ema_fast      2.877949e+04
# ema_slow      2.991789e+04
# macd         -1.138409e+03
# signal       -4.842657e+02
# histogram    -6.541432e+02
# prev_close    2.657453e+04
# TR            4.970070e+03
# ATR           1.704789e+03
# volume_pct             NaN
# atr_pct                NaN
# EMA_20        2.940842e+04
# EMA_50        3.059870e+04
# plus_dm       0.000000e+00
# minus_dm      4.634230e+03
# plus_di       5.260914e+00
# minus_di      6.213501e+01
# dx            8.438803e+01
# ADX           8.438803e+01
# BB_middle              NaN
# BB_std                 NaN
# BB_upper               NaN
# BB_lower               NaN
# Name: 2022-06-13 00:00:00+00:00, dtype: float64
# 2025-02-22 06:47:08,356 - INFO - Current data:
# open          2.248527e+04
# high          2.336288e+04
# low           2.084600e+04
# close         2.213641e+04
# volume        1.872016e+05
# volume_usd    4.143972e+09
# ema_fast      2.789374e+04
# ema_slow      2.938124e+04
# macd         -1.487498e+03
# signal       -6.386092e+02
# histogram    -8.488890e+02
# prev_close    2.248741e+04
# TR            2.516880e+03
# ATR           1.798924e+03
# volume_pct             NaN
# atr_pct                NaN
# EMA_20        2.871585e+04
# EMA_50        3.026685e+04
# plus_dm       0.000000e+00
# minus_dm      1.079770e+03
# plus_di       4.320869e+00
# minus_di      5.903552e+01
# dx            8.636011e+01
# ADX           8.465098e+01
# BB_middle              NaN
# BB_std                 NaN
# BB_upper               NaN
# BB_lower               NaN
# Name: 2022-06-14 00:00:00+00:00, dtype: float64
# 2025-02-22 06:47:08,358 - INFO - Current data:
# open          2.213642e+04
# high          2.280000e+04
# low           2.011162e+04
# close         2.258372e+04
# volume        2.007745e+05
# volume_usd    4.534235e+09
# ema_fast      2.718574e+04
# ema_slow      2.891245e+04
# macd         -1.726707e+03
# signal       -8.060088e+02
# histogram    -9.206979e+02
# prev_close    2.213641e+04
# TR            2.688380e+03
# ATR           1.799382e+03
# volume_pct             NaN
# atr_pct                NaN
# EMA_20        2.813184e+04
# EMA_50        2.996555e+04
# plus_dm       0.000000e+00
# minus_dm      7.343800e+02
# plus_di       3.743801e+00
# minus_di      5.659282e+01
# dx            8.759029e+01
# ADX           8.504289e+01
# BB_middle              NaN
# BB_std                 NaN
# BB_upper               NaN
# BB_lower               NaN
# Name: 2022-06-15 00:00:00+00:00, dtype: float64
# 2025-02-22 06:47:08,360 - INFO - Current data:
# open          2.258372e+04
# high          2.299573e+04
# low           2.023200e+04
# close         2.040131e+04
# volume        9.967359e+04
# volume_usd    2.033472e+09
# ema_fast      2.628115e+04
# ema_slow      2.832547e+04
# macd         -2.044322e+03
# signal       -9.965185e+02
# histogram    -1.047804e+03
# prev_close    2.258372e+04
# TR            2.763730e+03
# ATR           1.918616e+03
# volume_pct             NaN
# atr_pct                NaN
# EMA_20        2.739560e+04
# EMA_50        2.959048e+04
# plus_dm       1.957300e+02
# minus_dm     -0.000000e+00
# plus_di       4.403203e+00
# minus_di      4.599903e+01
# dx            8.252775e+01
# ADX           8.470753e+01
# BB_middle              NaN
# BB_std                 NaN
# BB_upper               NaN
# BB_lower               NaN
# Name: 2022-06-16 00:00:00+00:00, dtype: float64
# 2025-02-22 06:47:08,361 - INFO - Current data:
# open          2.040060e+04
# high          2.136543e+04
# low           2.024666e+04
# close         2.046881e+04
# volume        8.669434e+04
# volume_usd    1.774530e+09
# ema_fast      2.550617e+04
# ema_slow      2.778363e+04
# macd         -2.277462e+03
# signal       -1.193587e+03
# histogram    -1.083875e+03
# prev_close    2.040131e+04
# TR            1.118770e+03
# ATR           1.897340e+03
# volume_pct             NaN
# atr_pct                NaN
# EMA_20        2.673590e+04
# EMA_50        2.923277e+04
# plus_dm       0.000000e+00
# minus_dm     -0.000000e+00
# plus_di       3.858902e+00
# minus_di      4.031287e+01
# dx            8.252775e+01
# ADX           8.441690e+01
# BB_middle              NaN
# BB_std                 NaN
# BB_upper               NaN
# BB_lower               NaN
# Name: 2022-06-17 00:00:00+00:00, dtype: float64
# 2025-02-22 06:47:08,364 - INFO - Current data:
# open          2.046881e+04
# high          2.079206e+04
# low           1.762200e+04
# close         1.897079e+04
# volume        1.964417e+05
# volume_usd    3.726653e+09
# ema_fast      2.463479e+04
# ema_slow      2.717585e+04
# macd         -2.541064e+03
# signal       -1.400891e+03
# histogram    -1.140173e+03
# prev_close    2.046881e+04
# TR            3.170060e+03
# ATR           2.087781e+03
# volume_pct             NaN
# atr_pct                NaN
# EMA_20        2.599637e+04
# EMA_50        2.883034e+04
# plus_dm       0.000000e+00
# minus_dm      2.624660e+03
# plus_di       3.039317e+00
# minus_di      4.851293e+01
# dx            8.820879e+01
# ADX           8.492248e+01
# BB_middle              NaN
# BB_std                 NaN
# BB_upper               NaN
# BB_lower               NaN
# Name: 2022-06-18 00:00:00+00:00, dtype: float64
# 2025-02-22 06:47:08,366 - INFO - Current data:
# open          1.897079e+04
# high          2.081595e+04
# low           1.796041e+04
# close         2.057400e+04
# volume        1.283209e+05
# volume_usd    2.640074e+09
# ema_fast      2.409335e+04
# ema_slow      2.672055e+04
# macd         -2.627202e+03
# signal       -1.589554e+03
# histogram    -1.037648e+03
# prev_close    1.897079e+04
# TR            2.855540e+03
# ATR           2.244779e+03
# volume_pct             NaN
# atr_pct                NaN
# EMA_20        2.547995e+04
# EMA_50        2.850656e+04
# plus_dm       2.389000e+01
# minus_dm     -0.000000e+00
# plus_di       2.591751e+00
# minus_di      3.910399e+01
# dx            8.756827e+01
# ADX           8.527525e+01
# BB_middle              NaN
# BB_std                 NaN
# BB_upper               NaN
# BB_lower               NaN
# Name: 2022-06-19 00:00:00+00:00, dtype: float64
# 2025-02-22 06:47:08,369 - INFO - Current data:
# open          2.057400e+04
# high          2.109000e+04
# low           1.963703e+04
# close         2.057389e+04
# volume        1.090289e+05
# volume_usd    2.243149e+09
# ema_fast      2.362409e+04
# ema_slow      2.629664e+04
# macd         -2.672556e+03
# signal       -1.756170e+03
# histogram    -9.163857e+02
# prev_close    2.057400e+04
# TR            1.452970e+03
# ATR           2.214604e+03
# volume_pct             NaN
# atr_pct                NaN
# EMA_20        2.501271e+04
# EMA_50        2.819548e+04
# plus_dm       2.740500e+02
# minus_dm     -0.000000e+00
# plus_di       3.926744e+00
# minus_di      3.435189e+01
# dx            7.948336e+01
# ADX           8.450300e+01
# BB_middle              NaN
# BB_std                 NaN
# BB_upper               NaN
# BB_lower               NaN
# Name: 2022-06-20 00:00:00+00:00, dtype: float64
# 2025-02-22 06:47:08,372 - INFO - Current data:
# open          2.057390e+04
# high          2.172300e+04
# low           2.034840e+04
# close         2.072352e+04
# volume        1.043711e+05
# volume_usd    2.162936e+09
# ema_fast      2.323734e+04
# ema_slow      2.591229e+04
# macd         -2.674944e+03
# signal       -1.897520e+03
# histogram    -7.774248e+02
# prev_close    2.057389e+04
# TR            1.374600e+03
# ATR           2.143459e+03
# volume_pct             NaN
# atr_pct                NaN
# EMA_20        2.460421e+04
# EMA_50        2.790246e+04
# plus_dm       6.330000e+02
# minus_dm     -0.000000e+00
# plus_di       7.453698e+00
# minus_di      3.075981e+01
# dx            6.098920e+01
# ADX           8.136783e+01
# BB_middle              NaN
# BB_std                 NaN
# BB_upper               NaN
# BB_lower               NaN
# Name: 2022-06-21 00:00:00+00:00, dtype: float64
# 2025-02-22 06:47:08,374 - INFO - Current data:
# open          2.072351e+04
# high          2.090000e+04
# low           1.977051e+04
# close         1.998799e+04
# volume        9.213398e+04
# volume_usd    1.841573e+09
# ema_fast      2.280410e+04
# ema_slow      2.550372e+04
# macd         -2.699619e+03
# signal       -2.020920e+03
# histogram    -6.786997e+02
# prev_close    2.072352e+04
# TR            1.129490e+03
# ATR           2.118184e+03
# volume_pct             NaN
# atr_pct                NaN
# EMA_20        2.416457e+04
# EMA_50        2.759209e+04
# plus_dm       0.000000e+00
# minus_dm      5.778900e+02
# plus_di       6.536954e+00
# minus_di      3.061425e+01
# dx            6.480893e+01
# ADX           7.915997e+01
# BB_middle              NaN
# BB_std                 NaN
# BB_upper               NaN
# BB_lower               NaN
# Name: 2022-06-22 00:00:00+00:00, dtype: float64
# 2025-02-22 06:47:08,376 - INFO - Current data:
# open          1.998800e+04
# high          2.123300e+04
# low           1.989007e+04
# close         2.111013e+04
# volume        8.312709e+04
# volume_usd    1.754824e+09
# ema_fast      2.257824e+04
# ema_slow      2.520071e+04
# macd         -2.622476e+03
# signal       -2.113467e+03
# histogram    -5.090090e+02
# prev_close    1.998799e+04
# TR            1.342930e+03
# ATR           2.160114e+03
# volume_pct             NaN
# atr_pct                NaN
# EMA_20        2.387367e+04
# EMA_50        2.733789e+04
# plus_dm       3.330000e+02
# minus_dm     -0.000000e+00
# plus_di       7.610834e+00
# minus_di      2.601732e+01
# dx            5.473535e+01
# ADX           7.590336e+01
# BB_middle     2.600798e+04
# BB_std        4.775679e+03
# BB_upper      3.555933e+04
# BB_lower      1.645662e+04
# Name: 2022-06-23 00:00:00+00:00, dtype: float64
# 2025-02-22 06:47:08,378 - INFO - Current data:
# open          2.111012e+04
# high          2.155841e+04
# low           2.073672e+04
# close         2.123769e+04
# volume        7.743037e+04
# volume_usd    1.644442e+09
# ema_fast      2.239950e+04
# ema_slow      2.492740e+04
# macd         -2.527903e+03
# signal       -2.177226e+03
# histogram    -3.506771e+02
# prev_close    2.111013e+04
# TR            8.216900e+02
# ATR           2.109321e+03
# volume_pct             NaN
# atr_pct                NaN
# EMA_20        2.362263e+04
# EMA_50        2.709867e+04
# plus_dm       3.254100e+02
# minus_dm     -0.000000e+00
# plus_di       8.811859e+00
# minus_di      2.309132e+01
# dx            4.475875e+01
# ADX           7.175074e+01
# BB_middle     2.558811e+04
# BB_std        4.712259e+03
# BB_upper      3.501263e+04
# BB_lower      1.616360e+04
# Name: 2022-06-24 00:00:00+00:00, dtype: float64
# 2025-02-22 06:47:08,380 - INFO - Current data:
# open          2.123768e+04
# high          2.161450e+04
# low           2.090662e+04
# close         2.149119e+04
# volume        5.143168e+04
# volume_usd    1.105328e+09
# ema_fast      2.227839e+04
# ema_slow      2.469042e+04
# macd         -2.412031e+03
# signal       -2.213350e+03
# histogram    -1.986808e+02
# prev_close    2.123769e+04
# TR            7.078800e+02
# ATR           2.064139e+03
# volume_pct             NaN
# atr_pct                NaN
# EMA_20        2.341963e+04
# EMA_50        2.687877e+04
# plus_dm       5.609000e+01
# minus_dm     -0.000000e+00
# plus_di       8.166421e+00
# minus_di      2.045053e+01
# dx            4.292598e+01
# ADX           6.790744e+01
# BB_middle     2.517572e+04
# BB_std        4.595568e+03
# BB_upper      3.436686e+04
# BB_lower      1.598458e+04
# Name: 2022-06-25 00:00:00+00:00, dtype: float64
# 2025-02-22 06:47:08,383 - INFO - Current data:
# open          2.149118e+04
# high          2.188800e+04
# low           2.096473e+04
# close         2.103807e+04
# volume        5.327810e+04
# volume_usd    1.120868e+09
# ema_fast      2.211301e+04
# ema_slow      2.443853e+04
# macd         -2.325520e+03
# signal       -2.230607e+03
# histogram    -9.491342e+01
# prev_close    2.149119e+04
# TR            9.232700e+02
# ATR           1.988304e+03
# volume_pct             NaN
# atr_pct                NaN
# EMA_20        2.319282e+04
# EMA_50        2.664972e+04
# plus_dm       2.735000e+02
# minus_dm     -0.000000e+00
# plus_di       9.181566e+00
# minus_di      1.839979e+01
# dx            3.342193e+01
# ADX           6.330937e+01
# BB_middle     2.482501e+04
# BB_std        4.561931e+03
# BB_upper      3.394887e+04
# BB_lower      1.570115e+04
# Name: 2022-06-26 00:00:00+00:00, dtype: float64
# 2025-02-22 06:47:08,385 - INFO - Current data:
# open          2.103808e+04
# high          2.153985e+04
# low           2.051000e+04
# close         2.074256e+04
# volume        6.447500e+04
# volume_usd    1.337377e+09
# ema_fast      2.193029e+04
# ema_slow      2.418364e+04
# macd         -2.253353e+03
# signal       -2.234106e+03
# histogram    -1.924639e+01
# prev_close    2.103807e+04
# TR            1.029850e+03
# ATR           1.706860e+03
# volume_pct             NaN
# atr_pct                NaN
# EMA_20        2.295946e+04
# EMA_50        2.641807e+04
# plus_dm       0.000000e+00
# minus_dm      4.547300e+02
# plus_di       9.269446e+00
# minus_di      2.212807e+01
# dx            4.095428e+01
# ADX           6.032869e+01
# BB_middle     2.443661e+04
# BB_std        4.475368e+03
# BB_upper      3.338734e+04
# BB_lower      1.548587e+04
# Name: 2022-06-27 00:00:00+00:00, dtype: float64
# 2025-02-22 06:47:08,388 - INFO - Current data:
# open          2.074257e+04
# high          2.121210e+04
# low           2.020201e+04
# close         2.028129e+04
# volume        6.380108e+04
# volume_usd    1.293968e+09
# ema_fast      2.171042e+04
# ema_slow      2.391451e+04
# macd         -2.204091e+03
# signal       -2.229489e+03
# histogram     2.539731e+01
# prev_close    2.074256e+04
# TR            1.010090e+03
# ATR           1.599232e+03
# volume_pct    1.666667e+01
# atr_pct                NaN
# EMA_20        2.270440e+04
# EMA_50        2.617741e+04
# plus_dm       0.000000e+00
# minus_dm      3.079900e+02
# plus_di       8.574174e+00
# minus_di      2.303613e+01
# dx            4.575077e+01
# ADX           5.838497e+01
# BB_middle     2.405985e+04
# BB_std        4.409774e+03
# BB_upper      3.287940e+04
# BB_lower      1.524030e+04
# Name: 2022-06-28 00:00:00+00:00, dtype: float64
# 2025-02-22 06:47:08,389 - INFO - Volume or volatility below threshold. No signal generated.
# 2025-02-22 06:47:08,392 - INFO - Current data:
# open          2.028128e+04
# high          2.043231e+04
# low           1.985492e+04
# close         2.012301e+04
# volume        7.730904e+04
# volume_usd    1.555691e+09
# ema_fast      2.149876e+04
# ema_slow      2.365303e+04
# macd         -2.154263e+03
# signal       -2.217915e+03
# histogram     6.365237e+01
# prev_close    2.028129e+04
# TR            5.773900e+02
# ATR           1.448447e+03
# volume_pct    2.666667e+01
# atr_pct                NaN
# EMA_20        2.245855e+04
# EMA_50        2.593998e+04
# plus_dm       0.000000e+00
# minus_dm      3.470900e+02
# plus_di       8.204521e+00
# minus_di      2.523804e+01
# dx            5.093366e+01
# ADX           5.739146e+01
# BB_middle     2.367021e+04
# BB_std        4.304655e+03
# BB_upper      3.227952e+04
# BB_lower      1.506090e+04
# Name: 2022-06-29 00:00:00+00:00, dtype: float64
# 2025-02-22 06:47:08,393 - INFO - Volume or volatility below threshold. No signal generated.
# 2025-02-22 06:47:08,395 - INFO - Current data:
# open          2.012300e+04
# high          2.017908e+04
# low           1.862600e+04
# close         1.994221e+04
# volume        9.384665e+04
# volume_usd    1.871510e+09
# ema_fast      2.129122e+04
# ema_slow      2.339711e+04
# macd         -2.105885e+03
# signal       -2.200680e+03
# histogram     9.479479e+01
# prev_close    2.012301e+04
# TR            1.553080e+03
# ATR           1.361972e+03
# volume_pct    5.000000e+01
# atr_pct                NaN
# EMA_20        2.221890e+04
# EMA_50        2.570478e+04
# plus_dm       0.000000e+00
# minus_dm      1.228920e+03
# plus_di       7.562054e+00
# minus_di      3.529253e+01
# dx            6.470831e+01
# ADX           5.836704e+01
# BB_middle     2.327113e+04
# BB_std        4.161268e+03
# BB_upper      3.159367e+04
# BB_lower      1.494859e+04
# Name: 2022-06-30 00:00:00+00:00, dtype: float64
# 2025-02-22 06:47:08,398 - INFO - Current data:
# open          1.994221e+04
# high          2.091835e+04
# low           1.897500e+04
# close         1.927980e+04
# volume        1.118446e+05
# volume_usd    2.156341e+09
# ema_fast      2.102303e+04
# ema_slow      2.311316e+04
# macd         -2.090123e+03
# signal       -2.183671e+03
# histogram     9.354847e+01
# prev_close    1.994221e+04
# TR            1.943350e+03
# ATR           1.420871e+03
# volume_pct    6.333333e+01
# atr_pct                NaN
# EMA_20        2.193898e+04
# EMA_50        2.545282e+04
# plus_dm       7.392700e+02
# minus_dm     -0.000000e+00
# plus_di       1.321936e+01
# minus_di      2.931896e+01
# dx            3.784729e+01
# ADX           5.563107e+01
# BB_middle     2.278740e+04
# BB_std        3.873126e+03
# BB_upper      3.053365e+04
# BB_lower      1.504115e+04
# Name: 2022-07-01 00:00:00+00:00, dtype: float64
# 2025-02-22 06:47:08,401 - INFO - Current data:
# open          1.927980e+04
# high          1.946739e+04
# low           1.897701e+04
# close         1.925281e+04
# volume        4.618030e+04
# volume_usd    8.891006e+08
# ema_fast      2.078700e+04
# ema_slow      2.284693e+04
# macd         -2.059922e+03
# signal       -2.164633e+03
# histogram     1.047110e+02
# prev_close    1.927980e+04
# TR            4.903800e+02
# ATR           1.229465e+03
# volume_pct    1.000000e+01
# atr_pct                NaN
# EMA_20        2.168316e+04
# EMA_50        2.520968e+04
# plus_dm       0.000000e+00
# minus_dm     -0.000000e+00
# plus_di       1.324039e+01
# minus_di      2.936561e+01
# dx            3.784729e+01
# ADX           5.325990e+01
# BB_middle     2.231250e+04
# BB_std        3.519945e+03
# BB_upper      2.935239e+04
# BB_lower      1.527261e+04
# Name: 2022-07-02 00:00:00+00:00, dtype: float64
# 2025-02-22 06:47:08,402 - INFO - Volume or volatility below threshold. No signal generated.
# 2025-02-22 06:47:08,406 - INFO - Current data:
# open          1.925282e+04
# high          1.964763e+04
# low           1.878100e+04
# close         1.931583e+04
# volume        5.108747e+04
# volume_usd    9.867968e+08
# ema_fast      2.059085e+04
# ema_slow      2.260340e+04
# macd         -2.012555e+03
# signal       -2.141236e+03
# histogram     1.286817e+02
# prev_close    1.925281e+04
# TR            8.666300e+02
# ATR           1.087400e+03
# volume_pct    1.333333e+01
# atr_pct                NaN
# EMA_20        2.145770e+04
# EMA_50        2.497855e+04
# plus_dm       1.802400e+02
# minus_dm      1.960100e+02
# plus_di       1.518422e+01
# minus_di      3.117858e+01
# dx            3.449827e+01
# ADX           5.075835e+01
# BB_middle     2.187694e+04
# BB_std        3.157726e+03
# BB_upper      2.819239e+04
# BB_lower      1.556149e+04
# Name: 2022-07-03 00:00:00+00:00, dtype: float64
# 2025-02-22 06:47:08,407 - INFO - Volume or volatility below threshold. No signal generated.
# 2025-02-22 06:47:08,409 - INFO - Current data:
# open          1.931583e+04
# high          2.035401e+04
# low           1.905531e+04
# close         2.023671e+04
# volume        7.481405e+04
# volume_usd    1.513990e+09
# ema_fast      2.054363e+04
# ema_slow      2.244018e+04
# macd         -1.896553e+03
# signal       -2.103593e+03
# histogram     2.070398e+02
# prev_close    1.931583e+04
# TR            1.298700e+03
# ATR           1.076381e+03
# volume_pct    3.000000e+01
# atr_pct                NaN
# EMA_20        2.134141e+04
# EMA_50        2.479259e+04
# plus_dm       7.063800e+02
# minus_dm     -0.000000e+00
# plus_di       2.204444e+01
# minus_di      2.729807e+01
# dx            1.064726e+01
# ADX           4.541021e+01
# BB_middle     2.148201e+04
# BB_std        2.663946e+03
# BB_upper      2.680990e+04
# BB_lower      1.615412e+04
# Name: 2022-07-04 00:00:00+00:00, dtype: float64
# 2025-02-22 06:47:08,411 - INFO - Current data:
# open          2.023671e+04
# high          2.075000e+04
# low           1.930440e+04
# close         2.017583e+04
# volume        9.604114e+04
# volume_usd    1.937710e+09
# ema_fast      2.049459e+04
# ema_slow      2.228402e+04
# macd         -1.789430e+03
# signal       -2.055260e+03
# histogram     2.658295e+02
# prev_close    2.023671e+04
# TR            1.445600e+03
# ATR           1.081452e+03
# volume_pct    5.333333e+01
# atr_pct                NaN
# EMA_20        2.123041e+04
# EMA_50        2.461154e+04
# plus_dm       3.959900e+02
# minus_dm     -0.000000e+00
# plus_di       2.389779e+01
# minus_di      2.354738e+01
# dx            7.385582e-01
# ADX           3.945399e+01
# BB_middle     2.112537e+04
# BB_std        2.149950e+03
# BB_upper      2.542527e+04
# BB_lower      1.682547e+04
# Name: 2022-07-05 00:00:00+00:00, dtype: float64
# 2025-02-22 06:47:08,414 - INFO - Current data:
# open          2.017584e+04
# high          2.067522e+04
# low           1.976125e+04
# close         2.056451e+04
# volume        8.243958e+04
# volume_usd    1.695330e+09
# ema_fast      2.050391e+04
# ema_slow      2.216543e+04
# macd         -1.661521e+03
# signal       -1.994685e+03
# histogram     3.331639e+02
# prev_close    2.017583e+04
# TR            9.139700e+02
# ATR           1.066058e+03
# volume_pct    3.666667e+01
# atr_pct                NaN
# EMA_20        2.116699e+04
# EMA_50        2.445284e+04
# plus_dm       0.000000e+00
# minus_dm     -0.000000e+00
# plus_di       2.101050e+01
# minus_di      2.070242e+01
# dx            7.385582e-01
# ADX           3.429193e+01
# BB_middle     2.081096e+04
# BB_std        1.520661e+03
# BB_upper      2.385228e+04
# BB_lower      1.776964e+04
# Name: 2022-07-06 00:00:00+00:00, dtype: float64
# 2025-02-22 06:47:08,416 - INFO - Current data:
# open          2.056451e+04
# high          2.183810e+04
# low           2.025168e+04
# close         2.162498e+04
# volume        8.501458e+04
# volume_usd    1.838439e+09
# ema_fast      2.065339e+04
# ema_slow      2.212816e+04
# macd         -1.474773e+03
# signal       -1.914698e+03
# histogram     4.399257e+02
# prev_close    2.056451e+04
# TR            1.586420e+03
# ATR           1.083450e+03
# volume_pct    4.666667e+01
# atr_pct                NaN
# EMA_20        2.121061e+04
# EMA_50        2.434194e+04
# plus_dm       1.162880e+03
# minus_dm     -0.000000e+00
# plus_di       3.222762e+01
# minus_di      1.765408e+01
# dx            2.921620e+01
# ADX           3.361517e+01
# BB_middle     2.061298e+04
# BB_std        9.565953e+02
# BB_upper      2.252617e+04
# BB_lower      1.869979e+04
# Name: 2022-07-07 00:00:00+00:00, dtype: float64
# 2025-02-22 06:47:08,419 - INFO - Current data:
# open          2.162499e+04
# high          2.252737e+04
# low           2.118926e+04
# close         2.159475e+04
# volume        4.030816e+05
# volume_usd    8.704446e+09
# ema_fast      2.077890e+04
# ema_slow      2.209137e+04
# macd         -1.312471e+03
# signal       -1.822048e+03
# histogram     5.095772e+02
# prev_close    2.162498e+04
# TR            1.338110e+03
# ATR           1.120337e+03
# volume_pct    1.000000e+02
# atr_pct                NaN
# EMA_20        2.124719e+04
# EMA_50        2.423421e+04
# plus_dm       6.892700e+02
# minus_dm     -0.000000e+00
# plus_di       3.521412e+01
# minus_di      1.479645e+01
# dx            4.082672e+01
# ADX           3.457671e+01
# BB_middle     2.057727e+04
# BB_std        8.986169e+02
# BB_upper      2.237451e+04
# BB_lower      1.878004e+04
# Name: 2022-07-08 00:00:00+00:00, dtype: float64
# 2025-02-22 06:47:08,423 - INFO - Current data:
# open          2.159475e+04
# high          2.198000e+04
# low           2.132212e+04
# close         2.159183e+04
# volume        1.784178e+05
# volume_usd    3.852368e+09
# ema_fast      2.088729e+04
# ema_slow      2.205692e+04
# macd         -1.169629e+03
# signal       -1.721676e+03
# histogram     5.520466e+02
# prev_close    2.159475e+04
# TR            6.578800e+02
# ATR           1.116766e+03
# volume_pct    8.666667e+01
# atr_pct                NaN
# EMA_20        2.128001e+04
# EMA_50        2.413058e+04
# plus_dm       0.000000e+00
# minus_dm     -0.000000e+00
# plus_di       3.061650e+01
# minus_di      1.286460e+01
# dx            4.082672e+01
# ADX           3.541004e+01
# BB_middle     2.055549e+04
# BB_std        8.652276e+02
# BB_upper      2.228594e+04
# BB_lower      1.882503e+04
# Name: 2022-07-09 00:00:00+00:00, dtype: float64
# 2025-02-22 06:47:08,426 - INFO - Current data:
# open          2.159215e+04
# high          2.160765e+04
# low           2.065500e+04
# close         2.086247e+04
# volume        1.921882e+05
# volume_usd    4.009521e+09
# ema_fast      2.088398e+04
# ema_slow      2.197455e+04
# macd         -1.090563e+03
# signal       -1.624581e+03
# histogram     5.340186e+02
# prev_close    2.159183e+04
# TR            9.526500e+02
# ATR           1.118864e+03
# volume_pct    8.666667e+01
# atr_pct                NaN
# EMA_20        2.124025e+04
# EMA_50        2.400242e+04
# plus_dm       0.000000e+00
# minus_dm      6.671200e+02
# plus_di       2.648453e+01
# minus_di      1.907837e+01
# dx            1.625480e+01
# ADX           3.285601e+01
# BB_middle     2.048664e+04
# BB_std        7.590800e+02
# BB_upper      2.200480e+04
# BB_lower      1.896848e+04
# Name: 2022-07-10 00:00:00+00:00, dtype: float64
# 2025-02-22 06:47:08,428 - INFO - Current data:
# open          2.086111e+04
# high          2.086848e+04
# low           1.987523e+04
# close         1.996361e+04
# volume        1.375354e+05
# volume_usd    2.745703e+09
# ema_fast      2.076127e+04
# ema_slow      2.183586e+04
# macd         -1.074594e+03
# signal       -1.539968e+03
# histogram     4.653740e+02
# prev_close    2.086247e+04
# TR            9.932500e+02
# ATR           1.116250e+03
# volume_pct    7.666667e+01
# atr_pct                NaN
# EMA_20        2.111866e+04
# EMA_50        2.384404e+04
# plus_dm       0.000000e+00
# minus_dm      7.797700e+02
# plus_di       2.300702e+01
# minus_di      2.588748e+01
# dx            5.891167e+00
# ADX           2.926070e+01
# BB_middle     2.046913e+04
# BB_std        7.661450e+02
# BB_upper      2.200142e+04
# BB_lower      1.893684e+04
# Name: 2022-07-11 00:00:00+00:00, dtype: float64
# 2025-02-22 06:47:08,431 - INFO - Current data:
# open          1.996361e+04
# high          2.005942e+04
# low           1.924000e+04
# close         1.932875e+04
# volume        1.395065e+05
# volume_usd    2.696485e+09
# ema_fast      2.057026e+04
# ema_slow      2.166296e+04
# macd         -1.092692e+03
# signal       -1.471156e+03
# histogram     3.784642e+02
# prev_close    1.996361e+04
# TR            8.194200e+02
# ATR           1.102631e+03
# volume_pct    7.333333e+01
# atr_pct       2.000000e+01
# EMA_20        2.094820e+04
# EMA_50        2.366697e+04
# plus_dm       0.000000e+00
# minus_dm      6.352300e+02
# plus_di       2.018570e+01
# minus_di      3.039432e+01
# dx            2.018310e+01
# ADX           2.805035e+01
# BB_middle     2.042353e+04
# BB_std        7.993736e+02
# BB_upper      2.202228e+04
# BB_lower      1.882478e+04
# Name: 2022-07-12 00:00:00+00:00, dtype: float64
# 2025-02-22 06:47:08,431 - INFO - Volume or volatility below threshold. No signal generated.
# 2025-02-22 06:47:08,434 - INFO - Current data:
# open          1.933128e+04
# high          2.036661e+04
# low           1.891094e+04
# close         2.023487e+04
# volume        2.092502e+05
# volume_usd    4.234152e+09
# ema_fast      2.052555e+04
# ema_slow      2.156447e+04
# macd         -1.038923e+03
# signal       -1.404659e+03
# histogram     3.657362e+02
# prev_close    1.932875e+04
# TR            1.455670e+03
# ATR           1.165365e+03
# volume_pct    9.333333e+01
# atr_pct       3.666667e+01
# EMA_20        2.088026e+04
# EMA_50        2.353238e+04
# plus_dm       3.071900e+02
# minus_dm      3.290600e+02
# plus_di       2.006718e+01
# minus_di      2.868859e+01
# dx            1.768285e+01
# ADX           2.666802e+01
# BB_middle     2.047409e+04
# BB_std        7.415407e+02
# BB_upper      2.195717e+04
# BB_lower      1.899101e+04
# Name: 2022-07-13 00:00:00+00:00, dtype: float64
# 2025-02-22 06:47:08,438 - INFO - Current data:
# open          2.023487e+04
# high          2.090000e+04
# low           1.961607e+04
# close         2.058884e+04
# volume        1.748092e+05
# volume_usd    3.599119e+09
# ema_fast      2.053398e+04
# ema_slow      2.149718e+04
# macd         -9.631987e+02
# signal       -1.336742e+03
# histogram     3.735432e+02
# prev_close    2.023487e+04
# TR            1.283930e+03
# ATR           1.146140e+03
# volume_pct    8.000000e+01
# atr_pct       3.666667e+01
# EMA_20        2.085251e+04
# EMA_50        2.341694e+04
# plus_dm       5.333900e+02
# minus_dm     -0.000000e+00
# plus_di       2.388834e+01
# minus_di      2.528050e+01
# dx            2.831389e+00
# ADX           2.348980e+01
# BB_middle     2.047469e+04
# BB_std        7.416299e+02
# BB_upper      2.195795e+04
# BB_lower      1.899143e+04
# Name: 2022-07-14 00:00:00+00:00, dtype: float64
# 2025-02-22 06:47:08,441 - INFO - Current data:
# open          2.058884e+04
# high          2.120000e+04
# low           2.038229e+04
# close         2.083004e+04
# volume        1.433433e+05
# volume_usd    2.985847e+09
# ema_fast      2.057346e+04
# ema_slow      2.145117e+04
# macd         -8.777147e+02
# signal       -1.266122e+03
# histogram     3.884076e+02
# prev_close    2.058884e+04
# TR            8.177100e+02
# ATR           1.065737e+03
# volume_pct    8.000000e+01
# atr_pct       3.333333e+00
# EMA_20        2.085037e+04
# EMA_50        2.331550e+04
# plus_dm       3.000000e+02
# minus_dm     -0.000000e+00
# plus_di       2.601842e+01
# minus_di      2.356271e+01
# dx            4.952904e+00
# ADX           2.101821e+01
# BB_middle     2.048493e+04
# BB_std        7.448201e+02
# BB_upper      2.197457e+04
# BB_lower      1.899529e+04
# Name: 2022-07-15 00:00:00+00:00, dtype: float64
# 2025-02-22 06:47:08,443 - INFO - Volume or volatility below threshold. No signal generated.
# 2025-02-22 06:47:08,445 - INFO - Current data:
# open          2.083004e+04
# high          2.158894e+04
# low           2.047861e+04
# close         2.119560e+04
# volume        1.210117e+05
# volume_usd    2.564915e+09
# ema_fast      2.065641e+04
# ema_slow      2.143355e+04
# macd         -7.771368e+02
# signal       -1.190894e+03
# histogram     4.137570e+02
# prev_close    2.083004e+04
# TR            1.110330e+03
# ATR           1.110019e+03
# volume_pct    6.666667e+01
# atr_pct       2.666667e+01
# EMA_20        2.088325e+04
# EMA_50        2.323236e+04
# plus_dm       3.889400e+02
# minus_dm     -0.000000e+00
# plus_di       2.632160e+01
# minus_di      1.960636e+01
# dx            1.462126e+01
# ADX           2.016529e+01
# BB_middle     2.050381e+04
# BB_std        7.570056e+02
# BB_upper      2.201783e+04
# BB_lower      1.898980e+04
# Name: 2022-07-16 00:00:00+00:00, dtype: float64
# 2025-02-22 06:47:08,446 - INFO - Volume or volatility below threshold. No signal generated.
# 2025-02-22 06:47:08,448 - INFO - Current data:
# open          2.119560e+04
# high          2.168454e+04
# low           2.075001e+04
# close         2.079816e+04
# volume        1.182295e+05
# volume_usd    2.458955e+09
# ema_fast      2.067531e+04
# ema_slow      2.138973e+04
# macd         -7.144171e+02
# signal       -1.117590e+03
# histogram     4.031726e+02
# prev_close    2.119560e+04
# TR            9.345300e+02
# ATR           1.114869e+03
# volume_pct    6.333333e+01
# atr_pct       3.000000e+01
# EMA_20        2.087514e+04
# EMA_50        2.313690e+04
# plus_dm       9.560000e+01
# minus_dm     -0.000000e+00
# plus_di       2.385615e+01
# minus_di      1.691826e+01
# dx            1.701531e+01
# ADX           1.974529e+01
# BB_middle     2.053622e+04
# BB_std        7.513235e+02
# BB_upper      2.203887e+04
# BB_lower      1.903357e+04
# Name: 2022-07-17 00:00:00+00:00, dtype: float64
# 2025-02-22 06:47:08,450 - INFO - Current data:
# open          2.079958e+04
# high          2.277763e+04
# low           2.076245e+04
# close         2.243258e+04
# volume        2.399427e+05
# volume_usd    5.382535e+09
# ema_fast      2.090961e+04
# ema_slow      2.146165e+04
# macd         -5.520354e+02
# signal       -1.030581e+03
# histogram     4.785460e+02
# prev_close    2.079816e+04
# TR            2.015180e+03
# ATR           1.166046e+03
# volume_pct    9.666667e+01
# atr_pct       5.333333e+01
# EMA_20        2.102347e+04
# EMA_50        2.310928e+04
# plus_dm       1.093090e+03
# minus_dm     -0.000000e+00
# plus_di       3.226700e+01
# minus_di      1.401896e+01
# dx            3.942457e+01
# ADX           2.236919e+01
# BB_middle     2.058912e+04
# BB_std        8.352778e+02
# BB_upper      2.225968e+04
# BB_lower      1.891856e+04
# Name: 2022-07-18 00:00:00+00:00, dtype: float64
# 2025-02-22 06:47:08,453 - INFO - Current data:
# open          2.243258e+04
# high          2.380000e+04
# low           2.157954e+04
# close         2.339662e+04
# volume        2.637708e+05
# volume_usd    6.171344e+09
# ema_fast      2.124121e+04
# ema_slow      2.159509e+04
# macd         -3.538808e+02
# signal       -9.264735e+02
# histogram     5.725928e+02
# prev_close    2.243258e+04
# TR            2.220460e+03
# ATR           1.221394e+03
# volume_pct    9.666667e+01
# atr_pct       5.666667e+01
# EMA_20        2.124948e+04
# EMA_50        2.312055e+04
# plus_dm       1.022370e+03
# minus_dm     -0.000000e+00
# plus_di       3.785822e+01
# minus_di      1.159920e+01
# dx            5.309419e+01
# ADX           2.646586e+01
# BB_middle     2.067548e+04
# BB_std        1.000406e+03
# BB_upper      2.267629e+04
# BB_lower      1.867466e+04
# Name: 2022-07-19 00:00:00+00:00, dtype: float64
# ...
# EMA_20        9.877540e+04
# EMA_50        9.829214e+04
# plus_dm       1.334200e+02
# minus_dm      3.791200e+02
# plus_di       1.093302e+01
# minus_di      1.906840e+01
# dx            2.711663e+01
# ADX           3.449040e+01
# BB_middle     1.008667e+05
# BB_std        3.382613e+03
# BB_upper      1.076319e+05
# BB_lower      9.410150e+04
# Name: 2025-02-11 00:00:00+00:00, dtype: float64
# 2025-02-22 06:47:11,827 - INFO - Volume or volatility below threshold. No signal generated.
# 2025-02-22 06:47:11,828 - INFO - Current data:
# open          9.577821e+04
# high          9.811999e+04
# low           9.408823e+04
# close         9.786999e+04
# volume        2.915117e+04
# volume_usd    2.853024e+09
# ema_fast      9.817159e+04
# ema_slow      9.895548e+04
# macd         -7.838983e+02
# signal       -1.206932e+02
# histogram    -6.632051e+02
# prev_close    9.577820e+04
# TR            4.031760e+03
# ATR           4.126601e+03
# volume_pct    6.333333e+01
# atr_pct       2.666667e+01
# EMA_20        9.868917e+04
# EMA_50        9.827559e+04
# plus_dm       0.000000e+00
# minus_dm      7.886500e+02
# plus_di       9.380636e+00
# minus_di      1.890905e+01
# dx            3.368158e+01
# ADX           3.438255e+01
# BB_middle     1.005993e+05
# BB_std        3.342837e+03
# BB_upper      1.072849e+05
# BB_lower      9.391360e+04
# Name: 2025-02-12 00:00:00+00:00, dtype: float64
# 2025-02-22 06:47:11,830 - INFO - Volume or volatility below threshold. No signal generated.
# 2025-02-22 06:47:11,832 - INFO - Current data:
# open          9.787000e+04
# high          9.808391e+04
# low           9.521736e+04
# close         9.660814e+04
# volume        1.992178e+04
# volume_usd    1.924606e+09
# ema_fast      9.796313e+04
# ema_slow      9.879360e+04
# macd         -8.304720e+02
# signal       -2.298899e+02
# histogram    -6.005821e+02
# prev_close    9.786999e+04
# TR            2.866550e+03
# ATR           4.104291e+03
# volume_pct    2.333333e+01
# atr_pct       2.333333e+01
# EMA_20        9.849098e+04
# EMA_50        9.821020e+04
# plus_dm       0.000000e+00
# minus_dm     -0.000000e+00
# plus_di       8.174078e+00
# minus_di      1.647692e+01
# dx            3.368158e+01
# ADX           3.428909e+01
# BB_middle     1.004103e+05
# BB_std        3.432017e+03
# BB_upper      1.072744e+05
# BB_lower      9.354630e+04
# Name: 2025-02-13 00:00:00+00:00, dtype: float64
# 2025-02-22 06:47:11,833 - INFO - Volume or volatility below threshold. No signal generated.
# 2025-02-22 06:47:11,836 - INFO - Current data:
# open          9.660813e+04
# high          9.882600e+04
# low           9.625282e+04
# close         9.750048e+04
# volume        1.817303e+04
# volume_usd    1.771879e+09
# ema_fast      9.790144e+04
# ema_slow      9.870442e+04
# macd         -8.029776e+02
# signal       -3.180573e+02
# histogram    -4.849203e+02
# prev_close    9.660814e+04
# TR            2.573180e+03
# ATR           3.970089e+03
# volume_pct    2.000000e+01
# atr_pct       1.333333e+01
# EMA_20        9.839664e+04
# EMA_50        9.818236e+04
# plus_dm       7.420900e+02
# minus_dm     -0.000000e+00
# plus_di       9.815939e+00
# minus_di      1.476271e+01
# dx            2.012629e+01
# ADX           3.240072e+01
# BB_middle     1.002200e+05
# BB_std        3.457056e+03
# BB_upper      1.071341e+05
# BB_lower      9.330584e+04
# Name: 2025-02-14 00:00:00+00:00, dtype: float64
# 2025-02-22 06:47:11,837 - INFO - Volume or volatility below threshold. No signal generated.
# 2025-02-22 06:47:11,840 - INFO - Current data:
# open          9.750047e+04
# high          9.797226e+04
# low           9.722358e+04
# close         9.756966e+04
# volume        7.349377e+03
# volume_usd    7.170762e+08
# ema_fast      9.785720e+04
# ema_slow      9.862616e+04
# macd         -7.689558e+02
# signal       -3.874263e+02
# histogram    -3.815296e+02
# prev_close    9.750048e+04
# TR            7.486800e+02
# ATR           3.844695e+03
# volume_pct    3.333333e+00
# atr_pct       6.666667e+00
# EMA_20        9.831788e+04
# EMA_50        9.815834e+04
# plus_dm       0.000000e+00
# minus_dm     -0.000000e+00
# plus_di       8.784607e+00
# minus_di      1.321163e+01
# dx            2.012629e+01
# ADX           3.076413e+01
# BB_middle     9.987699e+04
# BB_std        3.264844e+03
# BB_upper      1.064067e+05
# BB_lower      9.334730e+04
# Name: 2025-02-15 00:00:00+00:00, dtype: float64
# 2025-02-22 06:47:11,841 - INFO - Volume or volatility below threshold. No signal generated.
# 2025-02-22 06:47:11,843 - INFO - Current data:
# open          9.756967e+04
# high          9.770447e+04
# low           9.604618e+04
# close         9.611812e+04
# volume        8.191425e+03
# volume_usd    7.873444e+08
# ema_fast      9.762533e+04
# ema_slow      9.845319e+04
# macd         -8.278654e+02
# signal       -4.551861e+02
# histogram    -3.726792e+02
# prev_close    9.756966e+04
# TR            1.658290e+03
# ATR           3.584101e+03
# volume_pct    6.666667e+00
# atr_pct       3.333333e+00
# EMA_20        9.810838e+04
# EMA_50        9.807833e+04
# plus_dm       0.000000e+00
# minus_dm      1.177400e+03
# plus_di       8.166877e+00
# minus_di      1.666268e+01
# dx            3.421650e+01
# ADX           3.122444e+01
# BB_middle     9.957345e+04
# BB_std        3.246666e+03
# BB_upper      1.060668e+05
# BB_lower      9.308011e+04
# Name: 2025-02-16 00:00:00+00:00, dtype: float64
# 2025-02-22 06:47:11,844 - INFO - Volume or volatility below threshold. No signal generated.
# 2025-02-22 06:47:11,847 - INFO - Current data:
# open          9.611812e+04
# high          9.704659e+04
# low           9.520500e+04
# close         9.578000e+04
# volume        1.649205e+04
# volume_usd    1.579608e+09
# ema_fast      9.737928e+04
# ema_slow      9.826883e+04
# macd         -8.895508e+02
# signal       -5.220115e+02
# histogram    -3.675393e+02
# prev_close    9.611812e+04
# TR            1.841590e+03
# ATR           2.910714e+03
# volume_pct    2.666667e+01
# atr_pct       3.333333e+00
# EMA_20        9.788663e+04
# EMA_50        9.798820e+04
# plus_dm       0.000000e+00
# minus_dm      8.411800e+02
# plus_di       8.715430e+00
# minus_di      2.163514e+01
# dx            4.256826e+01
# ADX           3.273695e+01
# BB_middle     9.924823e+04
# BB_std        3.201026e+03
# BB_upper      1.056503e+05
# BB_lower      9.284618e+04
# Name: 2025-02-17 00:00:00+00:00, dtype: float64
# 2025-02-22 06:47:11,849 - INFO - Volume or volatility below threshold. No signal generated.
# 2025-02-22 06:47:11,853 - INFO - Current data:
# open          9.578001e+04
# high          9.675391e+04
# low           9.338809e+04
# close         9.567174e+04
# volume        2.336819e+04
# volume_usd    2.235676e+09
# ema_fast      9.715161e+04
# ema_slow      9.808972e+04
# macd         -9.381132e+02
# signal       -5.860271e+02
# histogram    -3.520861e+02
# prev_close    9.578000e+04
# TR            3.365820e+03
# ATR           2.752394e+03
# volume_pct    5.000000e+01
# atr_pct       3.333333e+00
# EMA_20        9.767569e+04
# EMA_50        9.789736e+04
# plus_dm       0.000000e+00
# minus_dm      1.816910e+03
# plus_di       7.987851e+00
# minus_di      2.863060e+01
# dx            5.637254e+01
# ADX           3.588836e+01
# BB_middle     9.888028e+04
# BB_std        3.053102e+03
# BB_upper      1.049865e+05
# BB_lower      9.277408e+04
# Name: 2025-02-18 00:00:00+00:00, dtype: float64
# 2025-02-22 06:47:11,855 - INFO - Volume or volatility below threshold. No signal generated.
# 2025-02-22 06:47:11,858 - INFO - Current data:
# open          9.567174e+04
# high          9.689999e+04
# low           9.502999e+04
# close         9.664437e+04
# volume        1.643851e+04
# volume_usd    1.588689e+09
# ema_fast      9.708398e+04
# ema_slow      9.799004e+04
# macd         -9.060656e+02
# signal       -6.352638e+02
# histogram    -2.708018e+02
# prev_close    9.567174e+04
# TR            1.870000e+03
# ATR           2.672108e+03
# volume_pct    3.000000e+01
# atr_pct       3.333333e+00
# EMA_20        9.757747e+04
# EMA_50        9.784822e+04
# plus_dm       1.460800e+02
# minus_dm     -0.000000e+00
# plus_di       7.859718e+00
# minus_di      2.555872e+01
# dx            5.296179e+01
# ADX           3.816482e+01
# BB_middle     9.855618e+04
# BB_std        2.826003e+03
# BB_upper      1.042082e+05
# BB_lower      9.290418e+04
# Name: 2025-02-19 00:00:00+00:00, dtype: float64
# 2025-02-22 06:47:11,859 - INFO - Volume or volatility below threshold. No signal generated.
# 2025-02-22 06:47:11,862 - INFO - Current data:
# open          9.664437e+04
# high          9.871136e+04
# low           9.641509e+04
# close         9.830500e+04
# volume        1.705739e+04
# volume_usd    1.676827e+09
# ema_fast      9.724678e+04
# ema_slow      9.801176e+04
# macd         -7.649838e+02
# signal       -6.552207e+02
# histogram    -1.097631e+02
# prev_close    9.664437e+04
# TR            2.296270e+03
# ATR           2.590173e+03
# volume_pct    3.333333e+01
# atr_pct       3.333333e+00
# EMA_20        9.764676e+04
# EMA_50        9.786613e+04
# plus_dm       1.811370e+03
# minus_dm     -0.000000e+00
# plus_di       1.635155e+01
# minus_di      2.285159e+01
# dx            1.658040e+01
# ADX           3.528690e+01
# BB_middle     9.838358e+04
# BB_std        2.696253e+03
# BB_upper      1.037761e+05
# BB_lower      9.299108e+04
# Name: 2025-02-20 00:00:00+00:00, dtype: float64
# 2025-02-22 06:47:11,863 - INFO - Volume or volatility below threshold. No signal generated.
# 2025-02-22 06:47:11,865 - INFO - Current data:
# open          9.830501e+04
# high          9.947500e+04
# low           9.487195e+04
# close         9.618198e+04
# volume        3.224928e+04
# volume_usd    3.101800e+09
# ema_fast      9.710481e+04
# ema_slow      9.788557e+04
# macd         -7.807652e+02
# signal       -6.745353e+02
# histogram    -1.062299e+02
# prev_close    9.830500e+04
# TR            4.603050e+03
# ATR           2.596273e+03
# volume_pct    8.333333e+01
# atr_pct       6.666667e+00
# EMA_20        9.750726e+04
# EMA_50        9.780009e+04
# plus_dm       7.636400e+02
# minus_dm      1.543140e+03
# plus_di       1.805977e+01
# minus_di      2.768308e+01
# dx            2.103783e+01
# ADX           3.338702e+01
# BB_middle     9.814755e+04
# BB_std        2.616013e+03
# BB_upper      1.033796e+05
# BB_lower      9.291552e+04
# Name: 2025-02-21 00:00:00+00:00, dtype: float64
# 2025-02-22 06:47:11,867 - INFO - Volume or volatility below threshold. No signal generated.
# 2025-02-22 06:47:11,870 - INFO - Current data:
# open          9.618199e+04
# high          9.659500e+04
# low           9.577049e+04
# close         9.657389e+04
# volume        5.590665e+03
# volume_usd    5.399123e+08
# ema_fast      9.703402e+04
# ema_slow      9.779511e+04
# macd         -7.610933e+02
# signal       -6.878519e+02
# histogram    -7.324143e+01
# prev_close    9.618198e+04
# TR            8.245100e+02
# ATR           2.570024e+03
# volume_pct    3.333333e+00
# atr_pct       3.333333e+00
# EMA_20        9.741836e+04
# EMA_50        9.775200e+04
# plus_dm       0.000000e+00
# minus_dm     -0.000000e+00
# plus_di       1.581167e+01
# minus_di      2.423705e+01
# dx            2.103783e+01
# ADX           3.174046e+01
# BB_middle     9.795708e+04
# BB_std        2.546656e+03
# BB_upper      1.030504e+05
# BB_lower      9.286377e+04
# Name: 2025-02-22 00:00:00+00:00, dtype: float64
# 2025-02-22 06:47:11,871 - INFO - Volume or volatility below threshold. No signal generated.
# 2025-02-22 06:47:11,877 - INFO -
# Performance Metrics:
# 2025-02-22 06:47:11,878 - INFO - total_trades: 45
# 2025-02-22 06:47:11,878 - INFO - win_rate: 53.333333333333336
# 2025-02-22 06:47:11,879 - INFO - profit_factor: 1.6286038720554727
# 2025-02-22 06:47:11,880 - INFO - average_profit: 1118.4921522589095
# 2025-02-22 06:47:11,880 - INFO - max_drawdown: 63920.74773172205
# 2025-02-22 06:47:11,880 - INFO - sharpe_ratio: 3.280255576037205
# 2025-02-22 06:47:11,881 - INFO - avg_holding_time: 3 days 06:56:00
# 2025-02-22 06:47:11,881 - INFO - aggregated_returns: 50332.14685165093
# 2025-02-22 06:47:11,882 - INFO - best_trade: 10892.782290584268
# 2025-02-22 06:47:11,882 - INFO - worst_trade: -10940.682150301056
# 2025-02-22 06:47:11,883 - INFO - average_trade_pct: 37.283071741963646
# 2025-02-22 06:47:11,885 - INFO - days_reviewed: 1300
# 2025-02-22 06:47:11,888 - INFO - trade_details: [{'timestamp': Timestamp('2022-06-27 00:00:00+0000', tz='UTC'), 'exit_time': Timestamp('2022-07-03 00:00:00+0000', tz='UTC'), 'entry_price': 20742.56, 'exit_price': 19315.83, 'pnl': 2507.639759558486, 'holding_days': 6, 'exit_reason': 'Max Hold Time'}, {'timestamp': Timestamp('2022-08-30 00:00:00+0000', tz='UTC'), 'exit_time': Timestamp('2022-09-05 00:00:00+0000', tz='UTC'), 'entry_price': 19811.66, 'exit_price': 19796.84, 'pnl': 47.146473406824995, 'holding_days': 6, 'exit_reason': 'Max Hold Time'}, {'timestamp': Timestamp('2022-09-26 00:00:00+0000', tz='UTC'), 'exit_time': Timestamp('2022-10-02 00:00:00+0000', tz='UTC'), 'entry_price': 19227.82, 'exit_price': 19056.8, 'pnl': 493.4126603042986, 'holding_days': 6, 'exit_reason': 'Max Hold Time'}, {'timestamp': Timestamp('2022-11-06 00:00:00+0000', tz='UTC'), 'exit_time': Timestamp('2022-11-08 00:00:00+0000', tz='UTC'), 'entry_price': 20905.58, 'exit_price': 18547.23, 'pnl': -10940.682150301056, 'holding_days': 2, 'exit_reason': 'Stop Loss'}, {'timestamp': Timestamp('2022-11-09 00:00:00+0000', tz='UTC'), 'exit_time': Timestamp('2022-11-10 00:00:00+0000', tz='UTC'), 'entry_price': 15922.81, 'exit_price': 17601.15, 'pnl': -5152.982818829043, 'holding_days': 1, 'exit_reason': 'Stop Loss'}, {'timestamp': Timestamp('2022-11-15 00:00:00+0000', tz='UTC'), 'exit_time': Timestamp('2022-11-21 00:00:00+0000', tz='UTC'), 'entry_price': 16900.57, 'exit_price': 15781.29, 'pnl': 2716.408613272388, 'holding_days': 6, 'exit_reason': 'Max Hold Time'}, {'timestamp': Timestamp('2022-11-23 00:00:00+0000', tz='UTC'), 'exit_time': Timestamp('2022-11-29 00:00:00+0000', tz='UTC'), 'entry_price': 16603.11, 'exit_price': 16442.53, 'pnl': 594.4891051406887, 'holding_days': 6, 'exit_reason': 'Max Hold Time'}, {'timestamp': Timestamp('2023-01-13 00:00:00+0000', tz='UTC'), 'exit_time': Timestamp('2023-01-14 00:00:00+0000', tz='UTC'), 'entry_price': 19930.01, 'exit_price': 20954.92, 'pnl': 7503.616171582025, 'holding_days': 1, 'exit_reason': 'Take Profit 1'}, {'timestamp': Timestamp('2023-01-19 00:00:00+0000', tz='UTC'), 'exit_time': Timestamp('2023-01-20 00:00:00+0000', tz='UTC'), 'entry_price': 21071.59, 'exit_price': 22667.21, 'pnl': 6798.123761160952, 'holding_days': 1, 'exit_reason': 'Take Profit 1'}, {'timestamp': Timestamp('2023-01-29 00:00:00+0000', tz='UTC'), 'exit_time': Timestamp('2023-01-30 00:00:00+0000', tz='UTC'), 'entry_price': 23742.3, 'exit_price': 22826.15, 'pnl': -3036.467630361594, 'holding_days': 1, 'exit_reason': 'Stop Loss'}, {'timestamp': Timestamp('2023-02-02 00:00:00+0000', tz='UTC'), 'exit_time': Timestamp('2023-02-08 00:00:00+0000', tz='UTC'), 'entry_price': 23488.94, 'exit_price': 22963.0, 'pnl': -1689.1093848331363, 'holding_days': 6, 'exit_reason': 'Max Hold Time'}, {'timestamp': Timestamp('2023-02-23 00:00:00+0000', tz='UTC'), 'exit_time': Timestamp('2023-03-01 00:00:00+0000', tz='UTC'), 'entry_price': 23940.2, 'exit_price': 23628.97, 'pnl': -929.4027976661936, 'holding_days': 6, 'exit_reason': 'Max Hold Time'}, {'timestamp': Timestamp('2023-03-16 00:00:00+0000', tz='UTC'), 'exit_time': Timestamp('2023-03-17 00:00:00+0000', tz='UTC'), 'entry_price': 24998.78, 'exit_price': 27395.13, 'pnl': 6002.8306376867295, 'holding_days': 1, 'exit_reason': 'Take Profit 1'}, {'timestamp': Timestamp('2023-03-21 00:00:00+0000', tz='UTC'), 'exit_time': Timestamp('2023-03-27 00:00:00+0000', tz='UTC'), 'entry_price': 28105.47, 'exit_price': 27124.91, 'pnl': -1904.935294166624, 'holding_days': 6, 'exit_reason': 'Max Hold Time'}, {'timestamp': Timestamp('2023-06-16 00:00:00+0000', tz='UTC'), 'exit_time': Timestamp('2023-06-20 00:00:00+0000', tz='UTC'), 'entry_price': 26345.0, 'exit_price': 28307.99, 'pnl': -6062.108138513188, 'holding_days': 4, 'exit_reason': 'Stop Loss'}, {'timestamp': Timestamp('2023-07-04 00:00:00+0000', tz='UTC'), 'exit_time': Timestamp('2023-07-10 00:00:00+0000', tz='UTC'), 'entry_price': 30766.51, 'exit_price': 30411.57, 'pnl':  ...
# 2025-02-22 06:47:11,893 - INFO - Trade details exported to trade_details.csv
# 2025-02-22 06:47:11,904 - INFO - Successful trades exported to successful_trades.csv
# 2025-02-22 06:47:11,907 - INFO - Failed trades exported to failed_trades.csv
# 2025-02-22 06:47:11,915 - INFO - Signals and parameters exported to signals_and_parameters.csv
